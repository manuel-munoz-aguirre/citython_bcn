# %% [markdown]
# # Google API to obtain restaurants information
# ## Google Places API
# ### Citython 2018
# #### November 10th 2018

# %%
### Libraries: 

#import urllib, json
import urllib.request
import json
import pandas as pd

# %%
api_key = "AIzaSyAM4aXYGyS7Q8rxQ-6lijvxecBpGuhFxCQ"

# %%
#Grabbing and parsing the JSON data

def GoogPlac(lat,lng,radius,types,key):
    #making the url
    AUTH_KEY = key
    LOCATION = str(lat) + "," + str(lng)
    RADIUS = radius
    TYPES = types
    MyUrl = ('https://maps.googleapis.com/maps/api/place/nearbysearch/json'
           '?location=%s'
           '&radius=%s'
           '&types=%s'
           '&sensor=false&key=%s') % (LOCATION, RADIUS, TYPES, AUTH_KEY)
    
    #grabbing the JSON result
    response = urllib.request.urlopen(MyUrl)
    jsonRaw = response.read()
    jsonData = json.loads(jsonRaw)
    
    return jsonData

# %%
#Maximum radious = 50,000
#Location of Plaza Cataluya

a = GoogPlac(lat="41.386903", lng = "2.169404", radius = "50000", types = "restaurant", key = api_key)

# %%
a.keys()
# Out:
# [{'geometry': {'location': {'lat': 41.38479439999999, 'lng': 2.1750758},
#    'viewport': {'northeast': {'lat': 41.38615658029149,
#      'lng': 2.176370480291502},
#     'southwest': {'lat': 41.38345861970849, 'lng': 2.173672519708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#   'id': '3aa75509ece806d0302e64790d932fedfe6b1bfa',
#   'name': 'Hotel Barcelona Catedral',
#   'photos': [{'height': 1772,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114102022975157413296/photos">Hotel Barcelona Catedral</a>'],
#     'photo_reference': 'CmRaAAAAZTvyG-5ju-1cRL9QfB0e_QudtatarPgNWfL8pIyUjW7bjagZdwFGrnLBlaj_7Q-uBXqBq1n-M4NsaqQFKXo40V-e5_bgsS1pgzBanVJVVxCtD7e8ty-X05r3-EYFB6B3EhBYAXIki1QyG0sVMNA6MOHZGhQzCK9Hj99vE4T3EObNVXRl6w_dSg',
#     'width': 1329}],
#   'place_id': 'ChIJmRxO7_mipBIRdCiunF_6N_U',
#   'plus_code': {'compound_code': '95MG+W2 Barcelona, Spain',
#    'global_code': '8FH495MG+W2'},
#   'rating': 4.2,
# ...

# %%
a['results']
# Out:
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])

# %%
tmp = pd.DataFrame.from_dict(a['results'])

# %%
tmp
# Out:
#                                              geometry  \
# 0   {'location': {'lat': 41.38479439999999, 'lng':...
# 1   {'location': {'lat': 41.3881477, 'lng': 2.1599...
# 2   {'location': {'lat': 41.379926, 'lng': 2.18086...
# 3   {'location': {'lat': 41.3752352, 'lng': 2.1683...
# 4   {'location': {'lat': 41.39419739999999, 'lng':...
# 5   {'location': {'lat': 41.3858392, 'lng': 2.1947...
# 6   {'location': {'lat': 41.376801, 'lng': 2.14604...
# 7   {'location': {'lat': 41.38257420000001, 'lng':...
# 8   {'location': {'lat': 41.4037897, 'lng': 2.1912...
# 9   {'location': {'lat': 41.3990884, 'lng': 2.2021...
# 10  {'location': {'lat': 41.43546199999999, 'lng':...
# 11  {'location': {'lat': 41.27065959999999, 'lng':...
# 12  {'location': {'lat': 41.39722700000001, 'lng':...
# 13  {'location': {'lat': 41.384345, 'lng': 2.15152...
# 14  {'location': {'lat': 41.3921316, 'lng': 2.1523...
# 15  {'location': {'lat': 41.60829160000001, 'lng':...
# ...

# %%
#tmp.to_csv("/Users/raziel/Documents/citython_bcn/data_mining/tmp.Restaurant.python.csv", index=False)
