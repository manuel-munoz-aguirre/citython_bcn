# %%
import urllib.request
import json

# %%
api_key = "AIzaSyAM4aXYGyS7Q8rxQ-6lijvxecBpGuhFxCQ"

# %%
import urllib, json

#Grabbing and parsing the JSON data
def GoogPlac(lat,lng,radius,types,key):
    #making the url
    AUTH_KEY = key
    LOCATION = str(lat) + "," + str(lng)
    RADIUS = radius
    TYPES = types
    MyUrl = ('https://maps.googleapis.com/maps/api/place/nearbysearch/json'
           '?location=%s'
           '&radius=%s'
           '&types=%s'
           '&sensor=false&key=%s') % (LOCATION, RADIUS, TYPES, AUTH_KEY)
    
    #grabbing the JSON result
    response = urllib.request.urlopen(MyUrl)
    jsonRaw = response.read()
    jsonData = json.loads(jsonRaw)
    
    return jsonData

# %%
a = GoogPlac(lat="41.4102361", lng = "2.1734636", radius = "100", types = "restaurant", key = api_key)

# %%
a['results']
# Out:
# [{'geometry': {'location': {'lat': 41.4104799, 'lng': 2.174500000000001},
#    'viewport': {'northeast': {'lat': 41.4118278802915,
#      'lng': 2.175809630291501},
#     'southwest': {'lat': 41.4091299197085, 'lng': 2.173111669708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'e09510cf592882664140097365fbb4295798b085',
#   'name': 'Seoul Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4640,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106783530771214866250/photos">Carolina Martínez</a>'],
#     'photo_reference': 'CmRaAAAANzz4N9g822Xpsx7yqE3J5lDPKrm1HEgkoWvXWVdlwD77L8f6uFON-nz1bp5R5cJrCVjfMBkIM0LFMtVY1ogA4q72x8Q08KaXvOlaUHTG7WYrBOlYZdUeXUr1goPBj21lEhCwx0zAXgfxIADn7UAoFU3sGhRaxQKYWr09SgcJOUOTYR-XHbIqQg',
#     'width': 3480}],
#   'place_id': 'ChIJa0M4VcWipBIRVRuMZOWyTmQ',
#   'plus_code': {'compound_code': 'C56F+5Q Barcelona, Spain',
#    'global_code': '8FH4C56F+5Q'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJa0M4VcWipBIRVRuMZOWyTmQ',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 70, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4105624, 'lng': 2.174129600000001},
#    'viewport': {'northeast': {'lat': 41.4119114302915,
#      'lng': 2.175551580291502},
#     'southwest': {'lat': 41.4092134697085, 'lng': 2.172853619708499}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '9210b080cb5fd438706d12acb9ef83f7a2543ec8',
#   'name': 'Firo Tast Restaurant',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 901,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106799442106732381042/photos">Lydia Pastor Vidal</a>'],
#     'photo_reference': 'CmRaAAAAYfEtgUqtETtFxK-afcpgeb6wjbO36ZWOLv_PbLgyVnRKUPu_Hlyh0PaoBpU2Sx7PAlJ3XO2CIEafnjKenw5ncYTZ3fn1CF1Rn58km6XEXmKmBgWiri8Rd0zsJrvinu-JEhCZ4SwIe696YNLoT5b7wTw-GhQugUDUhFtiRW5KzPPJVCODkdIsrg',
#     'width': 1600}],
#   'place_id': 'ChIJZ_CcVsWipBIR833PHGaIK9I',
#   'plus_code': {'compound_code': 'C56F+6M Barcelona, Spain',
#    'global_code': '8FH4C56F+6M'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJZ_CcVsWipBIR833PHGaIK9I',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 83, Barcelona'},
#  {'geometry': {'location': {'lat': 41.409829, 'lng': 2.172821},
#    'viewport': {'northeast': {'lat': 41.41123158029151,
#      'lng': 2.174097380291502},
#     'southwest': {'lat': 41.40853361970851, 'lng': 2.171399419708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'cc9ae43f3b227a06bd92ba119d7e7b0538e8f0e5',
#   'name': 'Fukuya 8',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4160,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111704595082384285176/photos">Nil Ferré</a>'],
#     'photo_reference': 'CmRaAAAA1fHGQdA_BRy8NajyBWEBtt0XG2A3vj5oQFaSH3Vx76C_bJlCnBI-UAI9VRijSqN9UB3aIC0QeQVzUGNw8pL1ZwyHjrC3x2KpMRicnMmHMdzDKxbnlvqdjyj34UdkCu2FEhC2gg3q3tFFLwbBrgFVeFzXGhRdzZRZMVkDyl4JYQGWkGOkbjV22g',
#     'width': 3120}],
#   'place_id': 'ChIJITtzcsWipBIRwtPTqAV21Kk',
#   'plus_code': {'compound_code': 'C55F+W4 Barcelona, Spain',
#    'global_code': '8FH4C55F+W4'},
#   'rating': 4.2,
#   'reference': 'ChIJITtzcsWipBIRwtPTqAV21Kk',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Carrer de Sant Antoni Maria Claret, 186, Barcelona'},
#  {'geometry': {'location': {'lat': 41.410858, 'lng': 2.173924},
#    'viewport': {'northeast': {'lat': 41.41219238029149,
#      'lng': 2.175292230291502},
#     'southwest': {'lat': 41.40949441970849, 'lng': 2.172594269708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '007c1aa96637759aee46043882ae0de80120ea64',
#   'name': 'Estel de Sant Pau',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 768,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111403036019786004982/photos">Estel de Sant Pau</a>'],
#     'photo_reference': 'CmRaAAAABBuHP0A7pxfOzw6dl902eoctcM7DlowvOGZOCjoBKOwcgMw_wqOshJOQ9D3Rt1Y4m1syBZRjmLebYVwBJ3k34DJjOZKn9VqWBfOldkYfek1dnpt67Ih1KfPP8paHmcZ_EhBr7OQR6pcsUD83YKw0M98MGhSFTafZ-1HL3lRypuMNioblcYUiUg',
#     'width': 1024}],
#   'place_id': 'ChIJHX7o-c-ipBIRkhnsJ_faiMc',
#   'plus_code': {'compound_code': 'C56F+8H Barcelona, Spain',
#    'global_code': '8FH4C56F+8H'},
#   'rating': 4.3,
#   'reference': 'ChIJHX7o-c-ipBIRkhnsJ_faiMc',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Carrer de Sant Antoni Maria Claret, 157, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4098061, 'lng': 2.1726886},
#    'viewport': {'northeast': {'lat': 41.4111895302915,
#      'lng': 2.173990980291502},
#     'southwest': {'lat': 41.4084915697085, 'lng': 2.171293019708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '1f9f4ab034d589029de1e869754093dbfc306bd5',
#   'name': 'NOU FACE',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 540,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111680569655797032022/photos">Nou Face</a>'],
#     'photo_reference': 'CmRaAAAA4B7Op2yZ8ucRRkry-0qRkRfHIbIIvz-XKlR1Fef0mnaQ-Bq7ciibKriI71up0r2D7pVJYV8pIG4RjRIwMNNZf5jCLxy-4QENW0ET-O_O-TnyHCz6fVS136bRj7z2iOgREhB0_3Jx-jLm65u7O0c_PhMlGhTHA6Zii_gf9cbUxlVZkcddGahfyw',
#     'width': 960}],
#   'place_id': 'ChIJp23wbcWipBIRoaPXc77EBq4',
#   'plus_code': {'compound_code': 'C55F+W3 Barcelona, Spain',
#    'global_code': '8FH4C55F+W3'},
#   'price_level': 1,
#   'rating': 4.5,
#   'reference': 'ChIJp23wbcWipBIRoaPXc77EBq4',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Carrer de Sant Antoni Maria Claret, 190, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4107152, 'lng': 2.1741977},
#    'viewport': {'northeast': {'lat': 41.41206418029149,
#      'lng': 2.175546680291502},
#     'southwest': {'lat': 41.4093662197085, 'lng': 2.172848719708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '07da696dbe35c5bf4c92d4de86b5f4087f37d8b1',
#   'name': 'El Petit Firo',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3204,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100675118632959483080/photos">Damián García - Mediaty</a>'],
#     'photo_reference': 'CmRaAAAAMCdRjgAgZYIpjSNVTjE0E1K9bYELc9Zzaix1ZuXcJt9H6lmoirMwFPJBCn7LRtiGVz5EqnfKgkRWTNgGJ-rKDAP3PnghLUvVTg-NBHPN-jVl8zdrgOqbCIx75I-94joeEhAKbyBGPRTFPFRrre_KZyJyGhQ0OCdjJ81ihxnMuWIs4rcdnket8A',
#     'width': 4928}],
#   'place_id': 'ChIJxZBWUcWipBIR9K73ylT8zD0',
#   'plus_code': {'compound_code': 'C56F+7M Barcelona, Spain',
#    'global_code': '8FH4C56F+7M'},
#   'price_level': 2,
#   'rating': 3.9,
#   'reference': 'ChIJxZBWUcWipBIR9K73ylT8zD0',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda Gaudí 81 bajo, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4108674, 'lng': 2.174119799999999},
#    'viewport': {'northeast': {'lat': 41.41221643029149,
#      'lng': 2.175546530291502},
#     'southwest': {'lat': 41.40951846970849, 'lng': 2.172848569708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'a263b04e7b678d9fe6f6dd649dc4d1b26d8a2911',
#   'name': 'Green Kiss - Hospital Sant Pau',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109314969487609489003/photos">Wesley Mahler</a>'],
#     'photo_reference': 'CmRaAAAAmEqZx0-H20mAJDLLsHClsoY9k1a8-fHVA43Jgfn1Iz7Hly_fGX0iziZI04_8LE_qf60lILkQ0SbBauYnLyGmClR7mnLcwtFylCz0xBa574vJYzjwM7V5Aa2PiYOT2YaSEhDMamrmdnPqXrBlPllb-SqmGhR5GpEadS34JvbJvkdKhvmODK3pgg',
#     'width': 4032}],
#   'place_id': 'ChIJpZur-M-ipBIRc9jq2T1ubCU',
#   'plus_code': {'compound_code': 'C56F+8J Barcelona, Spain',
#    'global_code': '8FH4C56F+8J'},
#   'rating': 4.2,
#   'reference': 'ChIJpZur-M-ipBIRc9jq2T1ubCU',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 87, Barcelona'},
#  {'geometry': {'location': {'lat': 41.41064840000001, 'lng': 2.1744917},
#    'viewport': {'northeast': {'lat': 41.4119964302915,
#      'lng': 2.175802080291501},
#     'southwest': {'lat': 41.4092984697085, 'lng': 2.173104119708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '320d9dc1529ef4fcc29fd5761de7c2aee6211b84',
#   'name': 'Braseria Cal Ramon',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2048,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101466162141654879378/photos">Sara Pérez</a>'],
#     'photo_reference': 'CmRaAAAAcclnYj3irnx1iyJ9Id1lSN-h8NwPmNJJ5IenP4X_LkIh_DV5Uyzj0A5SsG-4oNu9UfRlS-bDhglFWOCvfrR618K-cNG_ZRzjLWqt8DqRo7khot-Mfm3kkeLQAoQC0oVAEhArYhHp_qgy5YlwegFW2z2sGhTfUdahaXPWWnp3UOx3erxGi9I0BA',
#     'width': 2048}],
#   'place_id': 'ChIJDRMW_s-ipBIRCHZ5Zsx_xnk',
#   'plus_code': {'compound_code': 'C56F+7Q Barcelona, Spain',
#    'global_code': '8FH4C56F+7Q'},
#   'price_level': 2,
#   'rating': 3.7,
#   'reference': 'ChIJDRMW_s-ipBIRCHZ5Zsx_xnk',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 74, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4106118, 'lng': 2.1733825},
#    'viewport': {'northeast': {'lat': 41.4119253802915,
#      'lng': 2.174778180291502},
#     'southwest': {'lat': 41.4092274197085, 'lng': 2.172080219708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '0d53e9759f5fa7887814dcb43bd6b4d2bf39ab89',
#   'name': 'Entre Tapes Sant Pau',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117825001017888706623/photos">Ramon Cleries I Robinat</a>'],
#     'photo_reference': 'CmRaAAAAsNjrAJ8eKhSFeWGqb6kfaqeSKOoc7P2hmsikfnGaf-OOWzPCTbDONApVULLtuynwIFXlCyueGfuHGkX17eKIlPZt_agfd4zK_BwrZmeXd1QU4B6tWeVypz-kM4oZnnKeEhDl9A9Rs43jhai9vnBWfjetGhSIC1Ja0HTsO82wwJfFA-_N8Tw_bQ',
#     'width': 4032}],
#   'place_id': 'ChIJRe9NXsWipBIRSYQYKfhdlXw',
#   'plus_code': {'compound_code': 'C56F+69 Barcelona, Spain',
#    'global_code': '8FH4C56F+69'},
#   'rating': 3,
#   'reference': 'ChIJRe9NXsWipBIRSYQYKfhdlXw',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Carrer de Sant Antoni Maria Claret, 137, Barcelona'},
#  {'geometry': {'location': {'lat': 41.41084190000001, 'lng': 2.1736885},
#    'viewport': {'northeast': {'lat': 41.41215468029151,
#      'lng': 2.175085230291502},
#     'southwest': {'lat': 41.40945671970851, 'lng': 2.172387269708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '35edb541359aa4f9db98d02e0d9e949a68094c93',
#   'name': 'La Cantina del Pintxo - Barcelona',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1200,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109277386489616796933/photos">La Cantina del Pintxo - Barcelona</a>'],
#     'photo_reference': 'CmRaAAAAo2xwB-PNrusH2sKGYY5BuRrdcpItuo-p4XvnI1C3kF6AWwhByU7EkXnzKBoiNO7RopsjS6rd1SA5BK7RUgCi0ertwx1eGIL6UrC8r_PvMqfGtrox95dwDAhKBabe3lJlEhCuG3i8YAek5PUo8Ub35jbyGhTiYP8F4pqPzU8bxj1W9br7pHViYQ',
#     'width': 1600}],
#   'place_id': 'ChIJQ-s59s-ipBIRO0Crk5YO52E',
#   'plus_code': {'compound_code': 'C56F+8F Barcelona, Spain',
#    'global_code': '8FH4C56F+8F'},
#   'rating': 2.9,
#   'reference': 'ChIJQ-s59s-ipBIRO0Crk5YO52E',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Carrer de Sant Antoni Maria Claret, 149, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4106677, 'lng': 2.1741804},
#    'viewport': {'northeast': {'lat': 41.4120167302915,
#      'lng': 2.175576880291502},
#     'southwest': {'lat': 41.4093187697085, 'lng': 2.172878919708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '954296f4fda68f3482f67b7dc64f2d37b28a5e13',
#   'name': 'Restaurante Vianda',
#   'place_id': 'ChIJR412VsWipBIR-hkbWRDB1UE',
#   'plus_code': {'compound_code': 'C56F+7M Barcelona, Spain',
#    'global_code': '8FH4C56F+7M'},
#   'rating': 4,
#   'reference': 'ChIJR412VsWipBIR-hkbWRDB1UE',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 85, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4102365, 'lng': 2.1745059},
#    'viewport': {'northeast': {'lat': 41.4115846302915,
#      'lng': 2.175820530291502},
#     'southwest': {'lat': 41.4088866697085, 'lng': 2.173122569708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'a44986cf8da2b9da24097ba87590fb4ad6bae0e0',
#   'name': 'Avinguda Gaudi Barcelonastuff Apartments',
#   'photos': [{'height': 4128,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113376982393271559150/photos">Ana Pereira</a>'],
#     'photo_reference': 'CmRaAAAAW02M9T7HTJSIVuYFQNLIwgeouRp9DQ9W2ClVSn0CDvi8-kqpmSQFc555pL0XOva3VY1tGkVBgD5BpyLLWrSnVIy1wBs-qqK2w8VeYoDv69P_L3tN6Hzt2UqL0iCj-7gNEhCIKBHksifXJtPM1hsA2R0NGhRnaTs05xsKFRxkUeQleb4akdFSTw',
#     'width': 2322}],
#   'place_id': 'ChIJ92IzrdqipBIR017NTTTqN60',
#   'plus_code': {'compound_code': 'C56F+3R Barcelona, Spain',
#    'global_code': '8FH4C56F+3R'},
#   'rating': 4.4,
#   'reference': 'ChIJ92IzrdqipBIR017NTTTqN60',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 66, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4096573, 'lng': 2.1741593},
#    'viewport': {'northeast': {'lat': 41.4110247802915,
#      'lng': 2.175533880291501},
#     'southwest': {'lat': 41.4083268197085, 'lng': 2.172835919708497}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': '2342ec76169a86dc565717c839c58ef7ceb61350',
#   'name': 'Bodega Celler Miquel',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 496,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108629045450189240780/photos">Bodega Celler Miquel</a>'],
#     'photo_reference': 'CmRaAAAAMZBBrS1FGuIvrETUfX35pKF1B680zAq_sZNjOhpCSbPTEsrsO9daRDnFIuBZQ8Vn2xM0x6urZKK_jESmXkYsE6ndBjPCEbP-pcCO0l3cqwNFxAvFQ8njLc9jxvfXUsfwEhBLxsT0JLBAYkHm4hHUZzVDGhRxXhiP9EbcXe5W0_12DCQE6HRZBQ',
#     'width': 750}],
#   'place_id': 'ChIJlaluRMWipBIRKgN_knFZTCU',
#   'plus_code': {'compound_code': 'C55F+VM Barcelona, Spain',
#    'global_code': '8FH4C55F+VM'},
#   'rating': 4.3,
#   'reference': 'ChIJlaluRMWipBIRKgN_knFZTCU',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Carrer de los Castillejos, 345, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4102365, 'lng': 2.1745059},
#    'viewport': {'northeast': {'lat': 41.4115846302915,
#      'lng': 2.175820530291502},
#     'southwest': {'lat': 41.4088866697085, 'lng': 2.173122569708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '9b5e7c1dded1c54336b56eeae2f884e11dca209e',
#   'name': 'CAPUCCINO',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1200,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109323987708759569836/photos">CAPUCCINO</a>'],
#     'photo_reference': 'CmRaAAAA0uqGwqF9HskswiXBBUOFuIgOi6CyE1wAQH8-e4Mqr8A9BBjjrp2LP7rDiV5e3zENygNhZGHJ0Kdm8xCsactSLxhd5V96sMAAMBgjy1K7gXcbzZSdXJ2Rw1CO2GrXvGFtEhAOrYcBfeWyCzGZmLpFNZB5GhT0NUbgYeYg9NXI3CQT5HakVgNnGA',
#     'width': 1800}],
#   'place_id': 'ChIJ92IzrdqipBIRxQbrPa9tNDI',
#   'plus_code': {'compound_code': 'C56F+3R Barcelona, Spain',
#    'global_code': '8FH4C56F+3R'},
#   'rating': 4.1,
#   'reference': 'ChIJ92IzrdqipBIRxQbrPa9tNDI',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 66, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4102365, 'lng': 2.1745059},
#    'viewport': {'northeast': {'lat': 41.4115846302915,
#      'lng': 2.175820530291502},
#     'southwest': {'lat': 41.4088866697085, 'lng': 2.173122569708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '03fca322505f4230cc3e6e3fdb014993d2adf64f',
#   'name': 'Restaurant Carta Capucchino',
#   'place_id': 'ChIJjWLANYCjpBIR9duBHyMFyOA',
#   'plus_code': {'compound_code': 'C56F+3R Barcelona, Spain',
#    'global_code': '8FH4C56F+3R'},
#   'reference': 'ChIJjWLANYCjpBIR9duBHyMFyOA',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 66, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4103408, 'lng': 2.1745025},
#    'viewport': {'northeast': {'lat': 41.4116888802915,
#      'lng': 2.175815830291502},
#     'southwest': {'lat': 41.4089909197085, 'lng': 2.173117869708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '6845400b9e43a66431bd2122f80883c05e8ae367',
#   'name': 'Free Fresh',
#   'place_id': 'ChIJEzvNrNqipBIRZVOA1DUTURk',
#   'plus_code': {'compound_code': 'C56F+4R Barcelona, Spain',
#    'global_code': '8FH4C56F+4R'},
#   'reference': 'ChIJEzvNrNqipBIRZVOA1DUTURk',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 68, Barcelona'},
#  {'geometry': {'location': {'lat': 41.41013989999999, 'lng': 2.1745095},
#    'viewport': {'northeast': {'lat': 41.4114880302915,
#      'lng': 2.175824880291502},
#     'southwest': {'lat': 41.4087900697085, 'lng': 2.173126919708499}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'f7721f036b48f1b9fa6ae1323c5762b84b62514b',
#   'name': 'Polentone',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111560452835833490678/photos">Emprendedor ypunto</a>'],
#     'photo_reference': 'CmRaAAAAxk1FBCetU1NUCB2c3mWGOsWWo1L7PfTcryWau7JM-T6GDMnji4qp5Z2oIrwyOw46sXAEgmgaR7adi69RZ04z8ZfQtjZxK9DcFMzKqLYZbcPeM9R42JsYOHG2ETVIFD24EhDMYq1GtXx2gwCSsb0OAESDGhTLaJNMpeReH15LkUa6iFSM5H0Rsw',
#     'width': 4032}],
#   'place_id': 'ChIJs4NVrdqipBIRH60aEFC2pqc',
#   'price_level': 1,
#   'rating': 4.2,
#   'reference': 'ChIJs4NVrdqipBIRH60aEFC2pqc',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 64, Barcelona'},
#  {'geometry': {'location': {'lat': 41.41013989999999, 'lng': 2.1745095},
#    'viewport': {'northeast': {'lat': 41.4114880302915,
#      'lng': 2.175824880291502},
#     'southwest': {'lat': 41.4087900697085, 'lng': 2.173126919708499}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '8f1ef177a7975b25c927d985976e451b70d1f5be',
#   'name': 'Polent One',
#   'photos': [{'height': 3092,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109220136683378912645/photos">Fermí Arimany</a>'],
#     'photo_reference': 'CmRaAAAAWRYCEO-4biQH5WV8z4NTK2oJNaGoZbs3r4SyJOfgSasFJeedCi5IPZaUI9w8R1V1oK_QRwIn9Yc2UI2usG3TymUsKzik6dkJ0JOlZ8iyY9AP7dosiOYGmPnM2ToSAIs2EhDKra3xnTwdl_YzqQOE8_evGhS74rTk9KLRHylOhJ8vND0BRqgaZQ',
#     'width': 2317}],
#   'place_id': 'ChIJs4NVrdqipBIRFhYnqcw2ehE',
#   'plus_code': {'compound_code': 'C56F+3R Barcelona, Spain',
#    'global_code': '8FH4C56F+3R'},
#   'reference': 'ChIJs4NVrdqipBIRFhYnqcw2ehE',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 64, Barcelona'},
#  {'geometry': {'location': {'lat': 41.4104799, 'lng': 2.174500000000001},
#    'viewport': {'northeast': {'lat': 41.4118278302915,
#      'lng': 2.175809630291501},
#     'southwest': {'lat': 41.4091298697085, 'lng': 2.173111669708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '873caf71dc390e5d8cb02038ba54b4a95dc07eda',
#   'name': '서울정',
#   'place_id': 'ChIJR7kmv9ujpBIR44Ys1rfjdlY',
#   'plus_code': {'compound_code': 'C56F+5Q Barcelona, Spain',
#    'global_code': '8FH4C56F+5Q'},
#   'reference': 'ChIJR7kmv9ujpBIR44Ys1rfjdlY',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': '70, Avinguda de Gaudí, Barcelona'},
#  {'geometry': {'location': {'lat': 41.41048, 'lng': 2.1745},
#    'viewport': {'northeast': {'lat': 41.4118279802915,
#      'lng': 2.175809630291501},
#     'southwest': {'lat': 41.4091300197085, 'lng': 2.173111669708498}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '7b6f0991d473a6daaa0b3663dedf20bced8697d6',
#   'name': '한식당',
#   'place_id': 'ChIJUypTq9qipBIR3x5uheu2T90',
#   'plus_code': {'compound_code': 'C56F+5Q Barcelona, Spain',
#    'global_code': '8FH4C56F+5Q'},
#   'rating': 5,
#   'reference': 'ChIJUypTq9qipBIR3x5uheu2T90',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'vicinity': 'Avinguda de Gaudí, 70, Barcelona'}]

# %%
a.keys()
# Out:
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])

# %%
a['results'][0]
# Out:
# {'geometry': {'location': {'lat': 41.4104799, 'lng': 2.174500000000001},
#   'viewport': {'northeast': {'lat': 41.4118278802915,
#     'lng': 2.175809630291501},
#    'southwest': {'lat': 41.4091299197085, 'lng': 2.173111669708498}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#  'id': 'e09510cf592882664140097365fbb4295798b085',
#  'name': 'Seoul Restaurant',
#  'opening_hours': {'open_now': False},
#  'photos': [{'height': 4640,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106783530771214866250/photos">Carolina Martínez</a>'],
#    'photo_reference': 'CmRaAAAANzz4N9g822Xpsx7yqE3J5lDPKrm1HEgkoWvXWVdlwD77L8f6uFON-nz1bp5R5cJrCVjfMBkIM0LFMtVY1ogA4q72x8Q08KaXvOlaUHTG7WYrBOlYZdUeXUr1goPBj21lEhCwx0zAXgfxIADn7UAoFU3sGhRaxQKYWr09SgcJOUOTYR-XHbIqQg',
#    'width': 3480}],
#  'place_id': 'ChIJa0M4VcWipBIRVRuMZOWyTmQ',
#  'plus_code': {'compound_code': 'C56F+5Q Barcelona, Spain',
#   'global_code': '8FH4C56F+5Q'},
#  'price_level': 2,
#  'rating': 4.4,
#  'reference': 'ChIJa0M4VcWipBIRVRuMZOWyTmQ',
#  'scope': 'GOOGLE',
#  'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#  'vicinity': 'Avinguda de Gaudí, 70, Barcelona'}

# %%
import pandas as pd

# %%
tmp = pd.DataFrame.from_dict(a['results'])

# %%
tmp
# Out:
#                                              geometry  \
# 0   {'location': {'lat': 41.4104799, 'lng': 2.1745...
# 1   {'location': {'lat': 41.4105624, 'lng': 2.1741...
# 2   {'location': {'lat': 41.409829, 'lng': 2.17282...
# 3   {'location': {'lat': 41.410858, 'lng': 2.17392...
# 4   {'location': {'lat': 41.4098061, 'lng': 2.1726...
# 5   {'location': {'lat': 41.4107152, 'lng': 2.1741...
# 6   {'location': {'lat': 41.4108674, 'lng': 2.1741...
# 7   {'location': {'lat': 41.41064840000001, 'lng':...
# 8   {'location': {'lat': 41.4106118, 'lng': 2.1733...
# 9   {'location': {'lat': 41.41084190000001, 'lng':...
# 10  {'location': {'lat': 41.4106677, 'lng': 2.1741...
# 11  {'location': {'lat': 41.4102365, 'lng': 2.1745...
# 12  {'location': {'lat': 41.4096573, 'lng': 2.1741...
# 13  {'location': {'lat': 41.4102365, 'lng': 2.1745...
# 14  {'location': {'lat': 41.4102365, 'lng': 2.1745...
# 15  {'location': {'lat': 41.4103408, 'lng': 2.1745...
# 16  {'location': {'lat': 41.41013989999999, 'lng':...
# 17  {'location': {'lat': 41.41013989999999, 'lng':...
# 18  {'location': {'lat': 41.4104799, 'lng': 2.1745...
# 19  {'location': {'lat': 41.41048, 'lng': 2.1745},...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                           id  \
# 0   e09510cf592882664140097365fbb4295798b085
# 1   9210b080cb5fd438706d12acb9ef83f7a2543ec8
# 2   cc9ae43f3b227a06bd92ba119d7e7b0538e8f0e5
# 3   007c1aa96637759aee46043882ae0de80120ea64
# 4   1f9f4ab034d589029de1e869754093dbfc306bd5
# 5   07da696dbe35c5bf4c92d4de86b5f4087f37d8b1
# 6   a263b04e7b678d9fe6f6dd649dc4d1b26d8a2911
# 7   320d9dc1529ef4fcc29fd5761de7c2aee6211b84
# 8   0d53e9759f5fa7887814dcb43bd6b4d2bf39ab89
# 9   35edb541359aa4f9db98d02e0d9e949a68094c93
# 10  954296f4fda68f3482f67b7dc64f2d37b28a5e13
# 11  a44986cf8da2b9da24097ba87590fb4ad6bae0e0
# 12  2342ec76169a86dc565717c839c58ef7ceb61350
# 13  9b5e7c1dded1c54336b56eeae2f884e11dca209e
# 14  03fca322505f4230cc3e6e3fdb014993d2adf64f
# 15  6845400b9e43a66431bd2122f80883c05e8ae367
# 16  f7721f036b48f1b9fa6ae1323c5762b84b62514b
# 17  8f1ef177a7975b25c927d985976e451b70d1f5be
# 18  873caf71dc390e5d8cb02038ba54b4a95dc07eda
# 19  7b6f0991d473a6daaa0b3663dedf20bced8697d6
#
#                                         name        opening_hours  \
# 0                           Seoul Restaurant  {'open_now': False}
# 1                       Firo Tast Restaurant   {'open_now': True}
# 2                                   Fukuya 8  {'open_now': False}
# 3                          Estel de Sant Pau   {'open_now': True}
# 4                                   NOU FACE   {'open_now': True}
# 5                              El Petit Firo   {'open_now': True}
# 6             Green Kiss - Hospital Sant Pau  {'open_now': False}
# 7                         Braseria Cal Ramon   {'open_now': True}
# 8                       Entre Tapes Sant Pau   {'open_now': True}
# 9          La Cantina del Pintxo - Barcelona   {'open_now': True}
# 10                        Restaurante Vianda                  NaN
# 11  Avinguda Gaudi Barcelonastuff Apartments                  NaN
# 12                      Bodega Celler Miquel  {'open_now': False}
# 13                                 CAPUCCINO   {'open_now': True}
# 14               Restaurant Carta Capucchino                  NaN
# 15                                Free Fresh                  NaN
# 16                                 Polentone   {'open_now': True}
# 17                                Polent One                  NaN
# 18                                       서울정                  NaN
# 19                                       한식당                  NaN
#
#                                                photos  \
# 0   [{'height': 4640, 'html_attributions': ['<a hr...
# 1   [{'height': 901, 'html_attributions': ['<a hre...
# 2   [{'height': 4160, 'html_attributions': ['<a hr...
# 3   [{'height': 768, 'html_attributions': ['<a hre...
# 4   [{'height': 540, 'html_attributions': ['<a hre...
# 5   [{'height': 3204, 'html_attributions': ['<a hr...
# 6   [{'height': 3024, 'html_attributions': ['<a hr...
# 7   [{'height': 2048, 'html_attributions': ['<a hr...
# 8   [{'height': 3024, 'html_attributions': ['<a hr...
# 9   [{'height': 1200, 'html_attributions': ['<a hr...
# 10                                                NaN
# 11  [{'height': 4128, 'html_attributions': ['<a hr...
# 12  [{'height': 496, 'html_attributions': ['<a hre...
# 13  [{'height': 1200, 'html_attributions': ['<a hr...
# 14                                                NaN
# 15                                                NaN
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 17  [{'height': 3092, 'html_attributions': ['<a hr...
# 18                                                NaN
# 19                                                NaN
#
#                        place_id  \
# 0   ChIJa0M4VcWipBIRVRuMZOWyTmQ
# 1   ChIJZ_CcVsWipBIR833PHGaIK9I
# 2   ChIJITtzcsWipBIRwtPTqAV21Kk
# 3   ChIJHX7o-c-ipBIRkhnsJ_faiMc
# 4   ChIJp23wbcWipBIRoaPXc77EBq4
# 5   ChIJxZBWUcWipBIR9K73ylT8zD0
# 6   ChIJpZur-M-ipBIRc9jq2T1ubCU
# 7   ChIJDRMW_s-ipBIRCHZ5Zsx_xnk
# 8   ChIJRe9NXsWipBIRSYQYKfhdlXw
# 9   ChIJQ-s59s-ipBIRO0Crk5YO52E
# 10  ChIJR412VsWipBIR-hkbWRDB1UE
# 11  ChIJ92IzrdqipBIR017NTTTqN60
# 12  ChIJlaluRMWipBIRKgN_knFZTCU
# 13  ChIJ92IzrdqipBIRxQbrPa9tNDI
# 14  ChIJjWLANYCjpBIR9duBHyMFyOA
# 15  ChIJEzvNrNqipBIRZVOA1DUTURk
# 16  ChIJs4NVrdqipBIRH60aEFC2pqc
# 17  ChIJs4NVrdqipBIRFhYnqcw2ehE
# 18  ChIJR7kmv9ujpBIR44Ys1rfjdlY
# 19  ChIJUypTq9qipBIR3x5uheu2T90
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': 'C56F+5Q Barcelona, Spain', ...          2.0     4.4
# 1   {'compound_code': 'C56F+6M Barcelona, Spain', ...          2.0     4.0
# 2   {'compound_code': 'C55F+W4 Barcelona, Spain', ...          NaN     4.2
# 3   {'compound_code': 'C56F+8H Barcelona, Spain', ...          NaN     4.3
# 4   {'compound_code': 'C55F+W3 Barcelona, Spain', ...          1.0     4.5
# 5   {'compound_code': 'C56F+7M Barcelona, Spain', ...          2.0     3.9
# 6   {'compound_code': 'C56F+8J Barcelona, Spain', ...          NaN     4.2
# 7   {'compound_code': 'C56F+7Q Barcelona, Spain', ...          2.0     3.7
# 8   {'compound_code': 'C56F+69 Barcelona, Spain', ...          NaN     3.0
# 9   {'compound_code': 'C56F+8F Barcelona, Spain', ...          NaN     2.9
# 10  {'compound_code': 'C56F+7M Barcelona, Spain', ...          NaN     4.0
# 11  {'compound_code': 'C56F+3R Barcelona, Spain', ...          NaN     4.4
# 12  {'compound_code': 'C55F+VM Barcelona, Spain', ...          NaN     4.3
# 13  {'compound_code': 'C56F+3R Barcelona, Spain', ...          NaN     4.1
# 14  {'compound_code': 'C56F+3R Barcelona, Spain', ...          NaN     NaN
# 15  {'compound_code': 'C56F+4R Barcelona, Spain', ...          NaN     NaN
# 16                                                NaN          1.0     4.2
# 17  {'compound_code': 'C56F+3R Barcelona, Spain', ...          NaN     NaN
# 18  {'compound_code': 'C56F+5Q Barcelona, Spain', ...          NaN     NaN
# 19  {'compound_code': 'C56F+5Q Barcelona, Spain', ...          NaN     5.0
#
#                       reference   scope  \
# 0   ChIJa0M4VcWipBIRVRuMZOWyTmQ  GOOGLE
# 1   ChIJZ_CcVsWipBIR833PHGaIK9I  GOOGLE
# 2   ChIJITtzcsWipBIRwtPTqAV21Kk  GOOGLE
# 3   ChIJHX7o-c-ipBIRkhnsJ_faiMc  GOOGLE
# 4   ChIJp23wbcWipBIRoaPXc77EBq4  GOOGLE
# 5   ChIJxZBWUcWipBIR9K73ylT8zD0  GOOGLE
# 6   ChIJpZur-M-ipBIRc9jq2T1ubCU  GOOGLE
# 7   ChIJDRMW_s-ipBIRCHZ5Zsx_xnk  GOOGLE
# 8   ChIJRe9NXsWipBIRSYQYKfhdlXw  GOOGLE
# 9   ChIJQ-s59s-ipBIRO0Crk5YO52E  GOOGLE
# 10  ChIJR412VsWipBIR-hkbWRDB1UE  GOOGLE
# 11  ChIJ92IzrdqipBIR017NTTTqN60  GOOGLE
# 12  ChIJlaluRMWipBIRKgN_knFZTCU  GOOGLE
# 13  ChIJ92IzrdqipBIRxQbrPa9tNDI  GOOGLE
# 14  ChIJjWLANYCjpBIR9duBHyMFyOA  GOOGLE
# 15  ChIJEzvNrNqipBIRZVOA1DUTURk  GOOGLE
# 16  ChIJs4NVrdqipBIRH60aEFC2pqc  GOOGLE
# 17  ChIJs4NVrdqipBIRFhYnqcw2ehE  GOOGLE
# 18  ChIJR7kmv9ujpBIR44Ys1rfjdlY  GOOGLE
# 19  ChIJUypTq9qipBIR3x5uheu2T90  GOOGLE
#
#                                                 types  \
# 0   [restaurant, point_of_interest, food, establis...
# 1   [bar, restaurant, point_of_interest, food, est...
# 2   [restaurant, point_of_interest, food, establis...
# 3   [restaurant, point_of_interest, food, establis...
# 4   [restaurant, point_of_interest, food, establis...
# 5   [bar, restaurant, point_of_interest, food, est...
# 6   [restaurant, point_of_interest, food, establis...
# 7   [restaurant, point_of_interest, food, establis...
# 8   [bar, restaurant, point_of_interest, food, est...
# 9   [restaurant, point_of_interest, food, establis...
# 10  [restaurant, point_of_interest, food, establis...
# 11  [restaurant, point_of_interest, food, establis...
# 12  [bar, restaurant, point_of_interest, food, est...
# 13  [bar, restaurant, point_of_interest, food, est...
# 14  [restaurant, point_of_interest, food, establis...
# 15  [restaurant, point_of_interest, food, establis...
# 16  [restaurant, point_of_interest, food, establis...
# 17  [restaurant, point_of_interest, food, establis...
# 18  [restaurant, point_of_interest, food, establis...
# 19  [restaurant, point_of_interest, food, establis...
#
#                                              vicinity
# 0                    Avinguda de Gaudí, 70, Barcelona
# 1                    Avinguda de Gaudí, 83, Barcelona
# 2   Carrer de Sant Antoni Maria Claret, 186, Barce...
# 3   Carrer de Sant Antoni Maria Claret, 157, Barce...
# 4   Carrer de Sant Antoni Maria Claret, 190, Barce...
# 5                   Avinguda Gaudí 81 bajo, Barcelona
# 6                    Avinguda de Gaudí, 87, Barcelona
# 7                    Avinguda de Gaudí, 74, Barcelona
# 8   Carrer de Sant Antoni Maria Claret, 137, Barce...
# 9   Carrer de Sant Antoni Maria Claret, 149, Barce...
# 10                   Avinguda de Gaudí, 85, Barcelona
# 11                   Avinguda de Gaudí, 66, Barcelona
# 12          Carrer de los Castillejos, 345, Barcelona
# 13                   Avinguda de Gaudí, 66, Barcelona
# 14                   Avinguda de Gaudí, 66, Barcelona
# 15                   Avinguda de Gaudí, 68, Barcelona
# 16                   Avinguda de Gaudí, 64, Barcelona
# 17                   Avinguda de Gaudí, 64, Barcelona
# 18                   70, Avinguda de Gaudí, Barcelona
# 19                   Avinguda de Gaudí, 70, Barcelona

# %%
#tmp.to_csv("/Users/raziel/Documents/citython_bcn/data_mining/tmp.Restaurant.python.csv", index=False)
