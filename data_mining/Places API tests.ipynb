# %%
import urllib.request
import json

# %%
api_key = "AIzaSyAM4aXYGyS7Q8rxQ-6lijvxecBpGuhFxCQ"

# %%
https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=api_key

# %%
import urllib, json

#Grabbing and parsing the JSON data
def GoogPlac(lat,lng,radius,types,key):
    #making the url
    AUTH_KEY = key
    LOCATION = str(lat) + "," + str(lng)
    RADIUS = radius
    TYPES = types
    MyUrl = ('https://maps.googleapis.com/maps/api/place/nearbysearch/json'
           '?location=%s'
           '&radius=%s'
           '&types=%s'
           '&sensor=false&key=%s') % (LOCATION, RADIUS, TYPES, AUTH_KEY)
    
    #grabbing the JSON result
    response = urllib.request.urlopen(MyUrl)
    jsonRaw = response.read()
    jsonData = json.loads(jsonRaw)
    
    return jsonData

# %%
a = GoogPlac(lat="41.4102361", lng = "2.1734636", radius = "100", types = "restaurant", key = api_key)

# %%
a
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIgEAAOVotCBfn4qDBq8OXJT-VtpEjY1SoDsq8Ta6BP7KYtg9IYyq2fN83XhXymjfS4zE4PqIEr3E9wCRWJBMAH0ymcFZ-GJ8hav2OEMol06NecRi4iIEX-3aRm-knC8UNksDBrFi_1PZV5hHCePWbI-LNAYaTiptYrqphUq6XU-riwaLOEdHChKDRb1uuc5KoOGvV244RxBr5WDGR2Lc9gp2T1ug2ajomeAjpn8CoTyfRxavHH9Cq4tuYznltD0kFNnc43YrLrA8q9dDcbGInPN63pugFprKoaTGgAZSFJ5rRqftPRDB0rekXtJ9sDBpOpEoAtx_Cu06OG88VYYNhQyOZKPFpOOO30x1UsDloOie1oBLncFSdDUyxKDMIzd8MzgNj1gxpSZ2pNV0Lz3UPCkOU8gSEJf0gLZKxHJgH2ZRh2YextwaFF8LTqrk4y0lT8tlV-WaERlqIanR',
#  'results': [{'geometry': {'location': {'lat': 41.4104799,
#      'lng': 2.174500000000001},
#     'viewport': {'northeast': {'lat': 41.4118278802915,
#       'lng': 2.175809630291501},
#      'southwest': {'lat': 41.4091299197085, 'lng': 2.173111669708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'e09510cf592882664140097365fbb4295798b085',
#    'name': 'Seoul Restaurant',
#    'opening_hours': {'open_now': False},
# ...
